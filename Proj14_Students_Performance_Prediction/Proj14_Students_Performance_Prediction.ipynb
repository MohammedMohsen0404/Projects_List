# %% [markdown]
# <a href="https://www.kaggle.com/code/mohammedmohsen0404/proj14-students-performance-prediction?scriptVersionId=192734814" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ---
# **<center><h1>Students Performance Prediction</h1></center>**
# <center><h3>Learning ML, DL through 100 Practical Projects</h3></center>
#
# ---

# %% [markdown]
# This dataset contains comprehensive information on 2,392 high school students, detailing their demographics, study habits, parental involvement, extracurricular activities, and academic performance. The target variable, GradeClass, classifies students' grades into distinct categories, providing a robust dataset for educational research, predictive modeling, and statistical analysis.

# %% [markdown]
# #**Import Libraries and Data**
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import norm, skew, boxcox
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
! pip install kaggle
! mkdir ~/.kaggle
! cp /content/drive/MyDrive/kaggle/kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d rabieelkharoua/students-performance-dataset
# !unzip students-performance-dataset.zip
# Out:
# Requirement already satisfied: kaggle in /opt/conda/lib/python3.10/site-packages (1.6.14)
# Requirement already satisfied: six>=1.10 in /opt/conda/lib/python3.10/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /opt/conda/lib/python3.10/site-packages (from kaggle) (2024.7.4)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.10/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from kaggle) (4.66.4)
# Requirement already satisfied: python-slugify in /opt/conda/lib/python3.10/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.10/site-packages (from kaggle) (1.26.18)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /opt/conda/lib/python3.10/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->kaggle) (3.6)
# cp: cannot stat '/content/drive/MyDrive/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.6.17 / client 1.6.14)
# Dataset URL: https://www.kaggle.com/datasets/rabieelkharoua/students-performance-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# Downloading students-performance-dataset.zip to /kaggle/working
# 100%|███████████████████████████████████████| 66.2k/66.2k [00:00<00:00, 488kB/s]
# 100%|███████████████████████████████████████| 66.2k/66.2k [00:00<00:00, 486kB/s]
# Archive:  students-performance-dataset.zip
#   inflating: Student_performance_data _.csv

# %%
data = pd.read_csv("Student_performance_data _.csv").copy()

# %% [markdown]
# # **Take a look at the data**
# ---

# %%
data.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0
# 4             0  1.288061         4.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
data.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# min           0.001057     0.000000     0.000000         0.000000
# 25%           5.043079     7.000000     0.000000         1.000000
# 50%           9.705363    15.000000     0.000000         2.000000
# 75%          14.408410    22.000000     1.000000         3.000000
# max          19.978094    29.000000     1.000000         4.000000
#
#        Extracurricular       Sports        Music  Volunteering          GPA  \
# count      2392.000000  2392.000000  2392.000000   2392.000000  2392.000000
# mean          0.383361     0.303512     0.196906      0.157191     1.906186
# std           0.486307     0.459870     0.397744      0.364057     0.915156
# min           0.000000     0.000000     0.000000      0.000000     0.000000
# 25%           0.000000     0.000000     0.000000      0.000000     1.174803
# 50%           0.000000     0.000000     0.000000      0.000000     1.893393
# 75%           1.000000     1.000000     0.000000      0.000000     2.622216
# max           1.000000     1.000000     1.000000      1.000000     4.000000
#
#         GradeClass
# count  2392.000000
# mean      2.983696
# std       1.233908
# min       0.000000
# 25%       2.000000
# 50%       4.000000
# 75%       4.000000
# max       4.000000

# %%
data['GradeClass'].value_counts()
# Out:
# GradeClass
# 4.0    1211
# 3.0     414
# 2.0     391
# 1.0     269
# 0.0     107
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (2392, 15)

# %% [markdown]
# # **Exploratory Data Analysis**
# ---

# %% [markdown]
# **Univariate Analysis**

# %%
data.drop('StudentID',axis=1,inplace=True)

# %%
numerical_data = data.select_dtypes(include='number')
numerical_data.hist(figsize=(10, 8),color = 'b')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.boxplot(numerical_data)
plt.show()

# %% [markdown]
# **Multivariate Analysis**

# %%
sns.pairplot(data.select_dtypes(include='number'),corner = True)
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(numerical_data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # **Data Cleaning**
# ---

# %% [markdown]
# **Handling Duplicate Rows**

# %%
duplicate_rows = data.duplicated()
print(f"Number of duplicate rows: {duplicate_rows.sum()}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# **Handling Missing Data**

# %%
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(10)
# Out:
#                    Total  Percent
# Age                    0      0.0
# Gender                 0      0.0
# Ethnicity              0      0.0
# ParentalEducation      0      0.0
# StudyTimeWeekly        0      0.0
# Absences               0      0.0
# Tutoring               0      0.0
# ParentalSupport        0      0.0
# Extracurricular        0      0.0
# Sports                 0      0.0

# %%
total = data.isnull().sum().sum()
print('Total Null values =' ,total)
# Out:
# Total Null values = 0

# %% [markdown]
# # **Data Preprocessing**
# ---

# %% [markdown]
# **Data splitting**

# %%
X = data.drop(['GradeClass'], axis = 1)
y = data['GradeClass']

xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.30, random_state = 11,stratify=y)
xtest, xval, ytest, yval = train_test_split(X, y, test_size = 0.50, random_state = 11,stratify=y)

# %% [markdown]
# **Data Normalization**

# %%
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)
xval = scaler.transform(xval)

# %%
from keras.utils import to_categorical

ytrain = to_categorical(ytrain, num_classes=5)

yval = to_categorical(yval, num_classes=5)

ytest = to_categorical(ytest, num_classes=5)
# Out:
# 2024-08-15 09:09:42.475018: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-15 09:09:42.475159: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-15 09:09:42.618382: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # **Modeling**
# ----

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import keras_tuner as kt

# Define the model-building function for the tuner
def build_model(hp):
    model = Sequential()
    model.add(Input(shape=xtrain.shape[1:]))

    # Hidden layers with tunable number of layers, units, and dropout rates
    for i in range(hp.Int('num_layers', 1, 3)):
        model.add(Dense(units=hp.Int(f'units_{i}', min_value=32, max_value=256, step=32), activation='relu'))
        model.add(Dropout(rate=hp.Float(f'dropout_{i}', min_value=0.1, max_value=0.5, step=0.1)))

    # Output layer
    model.add(Dense(5, activation='softmax'))

    # Compile the model
    model.compile(optimizer='Nadam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# Define a custom objective function to consider both validation accuracy and overfitting
def custom_objective(hp):
    model = build_model(hp)
    history = model.fit(xtrain, ytrain, epochs=100, validation_data=(xval, yval), batch_size=32, verbose=0)

    train_accuracy = history.history['accuracy'][-1]
    val_accuracy = history.history['val_accuracy'][-1]

    # Penalize large gaps between training and validation accuracy
    return val_accuracy - tf.abs(train_accuracy - val_accuracy)

# Setup the tuner with the custom objective
tuner = kt.RandomSearch(
    build_model,  # the model-building function
    objective=kt.Objective('val_accuracy', direction='max'),  # maximize validation accuracy
    max_trials=20,  # total number of trials
    executions_per_trial=2,  # number of models to average for each trial
    directory='my_dir',  # where to save the search results
    project_name='hyperparam_tuning_custom'  # a name for this search
)

# Run the search with the custom objective function
tuner.search(xtrain, ytrain,
             epochs=100,
             validation_data=(xval, yval),
             callbacks=[
                 EarlyStopping(monitor='val_accuracy', patience=15, mode='max'),
                 ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, mode='max')
             ])

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Print the best hyperparameters
print(f"Best number of layers: {best_hps.get('num_layers')}")
for i in range(best_hps.get('num_layers')):
    print(f"Layer {i}: {best_hps.get(f'units_{i}')} units, dropout: {best_hps.get(f'dropout_{i}')}")

# Train the best model
model = tuner.hypermodel.build(best_hps)
history = model.fit(xtrain, ytrain,
                    epochs=100,
                    validation_data=(xval, yval),
                    callbacks=[
                        EarlyStopping(monitor='val_accuracy', patience=15, mode='max'),
                        ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, mode='max')
                    ])

# Evaluate the model on the validation set
val_loss, val_accuracy = model.evaluate(xval, yval)
print(f'Validation Accuracy: {val_accuracy}')

# Predict using the trained model
predictions = model.predict(xval)
print(f'Sample Predictions: {predictions[:5]}')
# Out:
# Trial 20 Complete [00h 00m 39s]
# val_accuracy: 0.864130437374115
#
# Best val_accuracy So Far: 0.9013378024101257
# Total elapsed time: 00h 12m 06s
# Best number of layers: 3
# Layer 0: 224 units, dropout: 0.2
# Layer 1: 160 units, dropout: 0.1
# Layer 2: 96 units, dropout: 0.4
# Epoch 1/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.4602 - loss: 1.3032 - val_accuracy: 0.6664 - val_loss: 0.8959 - learning_rate: 0.0010
# Epoch 2/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6627 - loss: 0.8954 - val_accuracy: 0.7818 - val_loss: 0.8043 - learning_rate: 0.0010
# Epoch 3/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7408 - loss: 0.7681 - val_accuracy: 0.7793 - val_loss: 0.7556 - learning_rate: 0.0010
# Epoch 4/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7585 - loss: 0.7365 - val_accuracy: 0.7860 - val_loss: 0.7056 - learning_rate: 0.0010
# Epoch 5/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7612 - loss: 0.7268 - val_accuracy: 0.8311 - val_loss: 0.6634 - learning_rate: 0.0010
# Epoch 6/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7835 - loss: 0.6651 - val_accuracy: 0.8194 - val_loss: 0.6467 - learning_rate: 0.0010
# Epoch 7/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8130 - loss: 0.6367 - val_accuracy: 0.8261 - val_loss: 0.6282 - learning_rate: 0.0010
# Epoch 8/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8063 - loss: 0.6287 - val_accuracy: 0.8453 - val_loss: 0.6057 - learning_rate: 0.0010
# Epoch 9/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8065 - loss: 0.6095 - val_accuracy: 0.8386 - val_loss: 0.5778 - learning_rate: 0.0010
# Epoch 10/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8198 - loss: 0.5637 - val_accuracy: 0.8236 - val_loss: 0.5946 - learning_rate: 0.0010
# Epoch 11/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8213 - loss: 0.5649 - val_accuracy: 0.8503 - val_loss: 0.5463 - learning_rate: 0.0010
# Epoch 12/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8357 - loss: 0.5366 - val_accuracy: 0.8512 - val_loss: 0.5430 - learning_rate: 0.0010
# Epoch 13/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8468 - loss: 0.4923 - val_accuracy: 0.8428 - val_loss: 0.5605 - learning_rate: 0.0010
# Epoch 14/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8335 - loss: 0.5263 - val_accuracy: 0.8620 - val_loss: 0.5361 - learning_rate: 0.0010
# Epoch 15/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8515 - loss: 0.5176 - val_accuracy: 0.8662 - val_loss: 0.5267 - learning_rate: 0.0010
# Epoch 16/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8578 - loss: 0.4774 - val_accuracy: 0.8604 - val_loss: 0.5358 - learning_rate: 0.0010
# Epoch 17/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8549 - loss: 0.4449 - val_accuracy: 0.8645 - val_loss: 0.5112 - learning_rate: 0.0010
# Epoch 18/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8670 - loss: 0.4630 - val_accuracy: 0.8679 - val_loss: 0.5127 - learning_rate: 0.0010
# Epoch 19/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8661 - loss: 0.4562 - val_accuracy: 0.8570 - val_loss: 0.5212 - learning_rate: 0.0010
# Epoch 20/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8551 - loss: 0.4619 - val_accuracy: 0.8662 - val_loss: 0.5025 - learning_rate: 0.0010
# Epoch 21/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8726 - loss: 0.4375 - val_accuracy: 0.8687 - val_loss: 0.5053 - learning_rate: 0.0010
# Epoch 22/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8669 - loss: 0.4016 - val_accuracy: 0.8679 - val_loss: 0.4949 - learning_rate: 0.0010
# Epoch 23/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8884 - loss: 0.3975 - val_accuracy: 0.8754 - val_loss: 0.4864 - learning_rate: 0.0010
# Epoch 24/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8770 - loss: 0.4119 - val_accuracy: 0.8545 - val_loss: 0.5205 - learning_rate: 0.0010
# Epoch 25/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8766 - loss: 0.3742 - val_accuracy: 0.8671 - val_loss: 0.4848 - learning_rate: 0.0010
# Epoch 26/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8641 - loss: 0.4336 - val_accuracy: 0.8612 - val_loss: 0.5326 - learning_rate: 0.0010
# Epoch 27/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8844 - loss: 0.3733 - val_accuracy: 0.8704 - val_loss: 0.4843 - learning_rate: 0.0010
# Epoch 28/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8944 - loss: 0.3683 - val_accuracy: 0.8679 - val_loss: 0.4912 - learning_rate: 0.0010
# Epoch 29/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8774 - loss: 0.3549 - val_accuracy: 0.8737 - val_loss: 0.4755 - learning_rate: 0.0010
# Epoch 30/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8957 - loss: 0.3229 - val_accuracy: 0.8712 - val_loss: 0.4942 - learning_rate: 0.0010
# Epoch 31/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8847 - loss: 0.3553 - val_accuracy: 0.8737 - val_loss: 0.4908 - learning_rate: 0.0010
# Epoch 32/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8821 - loss: 0.3563 - val_accuracy: 0.8729 - val_loss: 0.5039 - learning_rate: 0.0010
# Epoch 33/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9078 - loss: 0.3028 - val_accuracy: 0.8771 - val_loss: 0.4702 - learning_rate: 0.0010
# Epoch 34/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9019 - loss: 0.3088 - val_accuracy: 0.8754 - val_loss: 0.5044 - learning_rate: 0.0010
# Epoch 35/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8967 - loss: 0.3198 - val_accuracy: 0.8746 - val_loss: 0.5005 - learning_rate: 0.0010
# Epoch 36/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8955 - loss: 0.3196 - val_accuracy: 0.8746 - val_loss: 0.4908 - learning_rate: 0.0010
# Epoch 37/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8904 - loss: 0.3192 - val_accuracy: 0.8771 - val_loss: 0.4890 - learning_rate: 0.0010
# Epoch 38/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9022 - loss: 0.3024 - val_accuracy: 0.8821 - val_loss: 0.4757 - learning_rate: 0.0010
# Epoch 39/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8955 - loss: 0.3256 - val_accuracy: 0.8779 - val_loss: 0.5219 - learning_rate: 0.0010
# Epoch 40/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8931 - loss: 0.3058 - val_accuracy: 0.8771 - val_loss: 0.4835 - learning_rate: 0.0010
# Epoch 41/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9092 - loss: 0.2680 - val_accuracy: 0.8846 - val_loss: 0.4802 - learning_rate: 0.0010
# Epoch 42/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9030 - loss: 0.2941 - val_accuracy: 0.8855 - val_loss: 0.5077 - learning_rate: 0.0010
# Epoch 43/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9116 - loss: 0.2528 - val_accuracy: 0.8880 - val_loss: 0.4996 - learning_rate: 0.0010
# Epoch 44/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9047 - loss: 0.2701 - val_accuracy: 0.8779 - val_loss: 0.5126 - learning_rate: 0.0010
# Epoch 45/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9170 - loss: 0.2668 - val_accuracy: 0.8813 - val_loss: 0.4945 - learning_rate: 0.0010
# Epoch 46/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9219 - loss: 0.2438 - val_accuracy: 0.8930 - val_loss: 0.4947 - learning_rate: 0.0010
# Epoch 47/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9207 - loss: 0.2414 - val_accuracy: 0.8804 - val_loss: 0.5155 - learning_rate: 0.0010
# Epoch 48/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9195 - loss: 0.2408 - val_accuracy: 0.8829 - val_loss: 0.5179 - learning_rate: 0.0010
# Epoch 49/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9080 - loss: 0.2798 - val_accuracy: 0.8838 - val_loss: 0.5267 - learning_rate: 0.0010
# Epoch 50/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9241 - loss: 0.2180 - val_accuracy: 0.8754 - val_loss: 0.5488 - learning_rate: 0.0010
# Epoch 51/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9186 - loss: 0.2436 - val_accuracy: 0.8905 - val_loss: 0.5146 - learning_rate: 0.0010
# Epoch 52/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9227 - loss: 0.2250 - val_accuracy: 0.8880 - val_loss: 0.5244 - learning_rate: 0.0010
# Epoch 53/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9187 - loss: 0.2265 - val_accuracy: 0.8821 - val_loss: 0.5356 - learning_rate: 0.0010
# Epoch 54/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9239 - loss: 0.2220 - val_accuracy: 0.8930 - val_loss: 0.5291 - learning_rate: 0.0010
# Epoch 55/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9196 - loss: 0.2303 - val_accuracy: 0.8921 - val_loss: 0.5377 - learning_rate: 0.0010
# Epoch 56/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9163 - loss: 0.2157 - val_accuracy: 0.8863 - val_loss: 0.5463 - learning_rate: 0.0010
# Epoch 57/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9241 - loss: 0.2339 - val_accuracy: 0.8888 - val_loss: 0.5195 - learning_rate: 5.0000e-04
# Epoch 58/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9325 - loss: 0.1858 - val_accuracy: 0.8938 - val_loss: 0.5364 - learning_rate: 5.0000e-04
# Epoch 59/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9289 - loss: 0.2010 - val_accuracy: 0.8905 - val_loss: 0.5408 - learning_rate: 5.0000e-04
# Epoch 60/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9454 - loss: 0.1901 - val_accuracy: 0.8921 - val_loss: 0.5574 - learning_rate: 5.0000e-04
# Epoch 61/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9318 - loss: 0.1853 - val_accuracy: 0.8938 - val_loss: 0.5442 - learning_rate: 5.0000e-04
# Epoch 62/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9236 - loss: 0.1896 - val_accuracy: 0.8955 - val_loss: 0.5394 - learning_rate: 5.0000e-04
# Epoch 63/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9307 - loss: 0.2008 - val_accuracy: 0.8980 - val_loss: 0.5459 - learning_rate: 5.0000e-04
# Epoch 64/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9458 - loss: 0.1738 - val_accuracy: 0.8955 - val_loss: 0.5480 - learning_rate: 5.0000e-04
# Epoch 65/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9371 - loss: 0.1898 - val_accuracy: 0.8905 - val_loss: 0.5510 - learning_rate: 5.0000e-04
# Epoch 66/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9449 - loss: 0.1738 - val_accuracy: 0.8930 - val_loss: 0.5580 - learning_rate: 5.0000e-04
# Epoch 67/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9388 - loss: 0.1630 - val_accuracy: 0.9013 - val_loss: 0.5596 - learning_rate: 5.0000e-04
# Epoch 68/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9373 - loss: 0.1781 - val_accuracy: 0.8980 - val_loss: 0.5902 - learning_rate: 5.0000e-04
# Epoch 69/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9335 - loss: 0.1907 - val_accuracy: 0.8972 - val_loss: 0.5637 - learning_rate: 5.0000e-04
# Epoch 70/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9549 - loss: 0.1516 - val_accuracy: 0.8955 - val_loss: 0.5709 - learning_rate: 5.0000e-04
# Epoch 71/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9361 - loss: 0.1815 - val_accuracy: 0.8988 - val_loss: 0.5667 - learning_rate: 5.0000e-04
# Epoch 72/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9360 - loss: 0.1777 - val_accuracy: 0.8855 - val_loss: 0.5815 - learning_rate: 5.0000e-04
# Epoch 73/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9341 - loss: 0.1862 - val_accuracy: 0.8930 - val_loss: 0.5736 - learning_rate: 5.0000e-04
# Epoch 74/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9367 - loss: 0.1816 - val_accuracy: 0.8905 - val_loss: 0.5915 - learning_rate: 5.0000e-04
# Epoch 75/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9339 - loss: 0.1763 - val_accuracy: 0.8913 - val_loss: 0.5707 - learning_rate: 5.0000e-04
# Epoch 76/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9416 - loss: 0.1565 - val_accuracy: 0.8921 - val_loss: 0.5758 - learning_rate: 5.0000e-04
# Epoch 77/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9349 - loss: 0.1636 - val_accuracy: 0.8896 - val_loss: 0.5909 - learning_rate: 5.0000e-04
# Epoch 78/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9533 - loss: 0.1397 - val_accuracy: 0.8946 - val_loss: 0.5965 - learning_rate: 2.5000e-04
# Epoch 79/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9632 - loss: 0.1271 - val_accuracy: 0.8938 - val_loss: 0.5989 - learning_rate: 2.5000e-04
# Epoch 80/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9441 - loss: 0.1476 - val_accuracy: 0.8938 - val_loss: 0.5999 - learning_rate: 2.5000e-04
# Epoch 81/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9494 - loss: 0.1402 - val_accuracy: 0.8905 - val_loss: 0.5958 - learning_rate: 2.5000e-04
# Epoch 82/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9567 - loss: 0.1300 - val_accuracy: 0.8930 - val_loss: 0.6007 - learning_rate: 2.5000e-04
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9016 - loss: 0.5853
# Validation Accuracy: 0.8929765820503235
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Sample Predictions: [[6.78249171e-06 1.30526786e-07 1.48998402e-06 7.85159318e-06
#   9.99983728e-01]
#  [6.40380323e-01 3.58238757e-01 4.05981817e-04 2.37073855e-05
#   9.51253693e-04]
#  [2.38300383e-01 7.57822096e-01 8.85911461e-04 1.88820690e-04
#   2.80280411e-03]
#  [6.68246746e-01 3.31703931e-01 4.86740589e-07 1.40303715e-08
#   4.88059304e-05]
#  [3.11033909e-05 1.66491307e-02 9.64693546e-01 1.26368525e-02
#   5.98931545e-03]]

# %%
model = Sequential(
    [Input(shape=xtrain.shape[1:]),
     Dense(192,'relu'),
         Dropout(0.2),
     Dense(128,'relu'),
          Dropout(0.2),
     Dense(32,'relu'),
          Dropout(0.1),
     Dense(5,'softmax')])

# %%
model.compile(optimizer='Nadam',loss='categorical_crossentropy',metrics=['F1Score'])

# %%
E = EarlyStopping(monitor='val_f1_score', patience=15, mode='max')
R = ReduceLROnPlateau(monitor='val_f1_score', factor=0.5, patience=10)

# %%
history = model.fit(xtrain,ytrain,epochs=1000,validation_data=[xval,yval],callbacks=[R,E])
# Out:
# Epoch 1/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - F1Score: 0.2053 - loss: 1.2478 - val_F1Score: 0.3688 - val_loss: 0.8897 - learning_rate: 0.0010
# Epoch 2/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.4236 - loss: 0.8612 - val_F1Score: 0.5813 - val_loss: 0.8050 - learning_rate: 0.0010
# Epoch 3/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.5529 - loss: 0.7568 - val_F1Score: 0.5741 - val_loss: 0.7468 - learning_rate: 0.0010
# Epoch 4/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.5317 - loss: 0.7537 - val_F1Score: 0.6057 - val_loss: 0.7050 - learning_rate: 0.0010
# Epoch 5/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.5643 - loss: 0.6478 - val_F1Score: 0.6287 - val_loss: 0.6597 - learning_rate: 0.0010
# Epoch 6/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.5710 - loss: 0.6436 - val_F1Score: 0.6097 - val_loss: 0.6477 - learning_rate: 0.0010
# Epoch 7/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.6285 - loss: 0.6447 - val_F1Score: 0.6400 - val_loss: 0.6325 - learning_rate: 0.0010
# Epoch 8/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.6299 - loss: 0.5743 - val_F1Score: 0.7056 - val_loss: 0.6119 - learning_rate: 0.0010
# Epoch 9/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.6605 - loss: 0.5903 - val_F1Score: 0.6867 - val_loss: 0.5996 - learning_rate: 0.0010
# Epoch 10/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.6681 - loss: 0.5952 - val_F1Score: 0.6492 - val_loss: 0.5968 - learning_rate: 0.0010
# Epoch 11/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.6590 - loss: 0.5507 - val_F1Score: 0.6970 - val_loss: 0.5733 - learning_rate: 0.0010
# Epoch 12/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7284 - loss: 0.5095 - val_F1Score: 0.6632 - val_loss: 0.5664 - learning_rate: 0.0010
# Epoch 13/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7114 - loss: 0.4990 - val_F1Score: 0.7222 - val_loss: 0.5569 - learning_rate: 0.0010
# Epoch 14/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.6900 - loss: 0.5348 - val_F1Score: 0.7841 - val_loss: 0.5548 - learning_rate: 0.0010
# Epoch 15/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7312 - loss: 0.5271 - val_F1Score: 0.7484 - val_loss: 0.5466 - learning_rate: 0.0010
# Epoch 16/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7455 - loss: 0.4532 - val_F1Score: 0.7655 - val_loss: 0.5408 - learning_rate: 0.0010
# Epoch 17/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7673 - loss: 0.4536 - val_F1Score: 0.7364 - val_loss: 0.5213 - learning_rate: 0.0010
# Epoch 18/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7248 - loss: 0.5256 - val_F1Score: 0.8059 - val_loss: 0.5237 - learning_rate: 0.0010
# Epoch 19/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7639 - loss: 0.4601 - val_F1Score: 0.7356 - val_loss: 0.5176 - learning_rate: 0.0010
# Epoch 20/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7589 - loss: 0.4512 - val_F1Score: 0.7277 - val_loss: 0.5182 - learning_rate: 0.0010
# Epoch 21/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7646 - loss: 0.4427 - val_F1Score: 0.7859 - val_loss: 0.5031 - learning_rate: 0.0010
# Epoch 22/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7135 - loss: 0.4703 - val_F1Score: 0.7918 - val_loss: 0.5062 - learning_rate: 0.0010
# Epoch 23/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7411 - loss: 0.4536 - val_F1Score: 0.7616 - val_loss: 0.5172 - learning_rate: 0.0010
# Epoch 24/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7337 - loss: 0.4500 - val_F1Score: 0.7517 - val_loss: 0.4956 - learning_rate: 0.0010
# Epoch 25/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7455 - loss: 0.3993 - val_F1Score: 0.7894 - val_loss: 0.5022 - learning_rate: 0.0010
# Epoch 26/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7826 - loss: 0.3974 - val_F1Score: 0.7937 - val_loss: 0.5000 - learning_rate: 0.0010
# Epoch 27/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7838 - loss: 0.3973 - val_F1Score: 0.7978 - val_loss: 0.4902 - learning_rate: 0.0010
# Epoch 28/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8130 - loss: 0.3916 - val_F1Score: 0.7631 - val_loss: 0.4862 - learning_rate: 0.0010
# Epoch 29/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7831 - loss: 0.3804 - val_F1Score: 0.7828 - val_loss: 0.4917 - learning_rate: 0.0010
# Epoch 30/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8181 - loss: 0.3793 - val_F1Score: 0.7849 - val_loss: 0.4818 - learning_rate: 0.0010
# Epoch 31/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7936 - loss: 0.3824 - val_F1Score: 0.8165 - val_loss: 0.4815 - learning_rate: 0.0010
# Epoch 32/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7751 - loss: 0.4005 - val_F1Score: 0.8096 - val_loss: 0.4890 - learning_rate: 0.0010
# Epoch 33/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7771 - loss: 0.3515 - val_F1Score: 0.8017 - val_loss: 0.4909 - learning_rate: 0.0010
# Epoch 34/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8058 - loss: 0.3846 - val_F1Score: 0.7952 - val_loss: 0.4818 - learning_rate: 0.0010
# Epoch 35/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7780 - loss: 0.3559 - val_F1Score: 0.8068 - val_loss: 0.4761 - learning_rate: 0.0010
# Epoch 36/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7878 - loss: 0.3718 - val_F1Score: 0.8091 - val_loss: 0.4770 - learning_rate: 0.0010
# Epoch 37/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8034 - loss: 0.3453 - val_F1Score: 0.7986 - val_loss: 0.4923 - learning_rate: 0.0010
# Epoch 38/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.7820 - loss: 0.3694 - val_F1Score: 0.8249 - val_loss: 0.4690 - learning_rate: 0.0010
# Epoch 39/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8220 - loss: 0.3210 - val_F1Score: 0.8090 - val_loss: 0.4927 - learning_rate: 0.0010
# Epoch 40/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.7886 - loss: 0.3448 - val_F1Score: 0.8089 - val_loss: 0.4782 - learning_rate: 0.0010
# Epoch 41/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7830 - loss: 0.3692 - val_F1Score: 0.8130 - val_loss: 0.4564 - learning_rate: 0.0010
# Epoch 42/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.7947 - loss: 0.3133 - val_F1Score: 0.7993 - val_loss: 0.4782 - learning_rate: 0.0010
# Epoch 43/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8029 - loss: 0.3201 - val_F1Score: 0.8076 - val_loss: 0.4706 - learning_rate: 0.0010
# Epoch 44/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8193 - loss: 0.3165 - val_F1Score: 0.8154 - val_loss: 0.4621 - learning_rate: 0.0010
# Epoch 45/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8078 - loss: 0.3174 - val_F1Score: 0.7991 - val_loss: 0.4894 - learning_rate: 0.0010
# Epoch 46/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8092 - loss: 0.3056 - val_F1Score: 0.8161 - val_loss: 0.4650 - learning_rate: 0.0010
# Epoch 47/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8533 - loss: 0.2704 - val_F1Score: 0.8192 - val_loss: 0.4739 - learning_rate: 0.0010
# Epoch 48/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8132 - loss: 0.2787 - val_F1Score: 0.8142 - val_loss: 0.4640 - learning_rate: 0.0010
# Epoch 49/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8030 - loss: 0.2995 - val_F1Score: 0.8212 - val_loss: 0.4770 - learning_rate: 0.0010
# Epoch 50/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8459 - loss: 0.2938 - val_F1Score: 0.8342 - val_loss: 0.4815 - learning_rate: 0.0010
# Epoch 51/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8459 - loss: 0.2639 - val_F1Score: 0.8147 - val_loss: 0.4736 - learning_rate: 0.0010
# Epoch 52/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8288 - loss: 0.2883 - val_F1Score: 0.8220 - val_loss: 0.4813 - learning_rate: 0.0010
# Epoch 53/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8592 - loss: 0.2680 - val_F1Score: 0.8222 - val_loss: 0.4785 - learning_rate: 0.0010
# Epoch 54/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8288 - loss: 0.2807 - val_F1Score: 0.8172 - val_loss: 0.4927 - learning_rate: 0.0010
# Epoch 55/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8649 - loss: 0.2791 - val_F1Score: 0.8143 - val_loss: 0.4845 - learning_rate: 0.0010
# Epoch 56/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8362 - loss: 0.2570 - val_F1Score: 0.8244 - val_loss: 0.4742 - learning_rate: 0.0010
# Epoch 57/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8583 - loss: 0.2667 - val_F1Score: 0.8307 - val_loss: 0.4793 - learning_rate: 0.0010
# Epoch 58/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8493 - loss: 0.2708 - val_F1Score: 0.8373 - val_loss: 0.4953 - learning_rate: 0.0010
# Epoch 59/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8540 - loss: 0.2843 - val_F1Score: 0.8343 - val_loss: 0.4985 - learning_rate: 0.0010
# Epoch 60/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8563 - loss: 0.2672 - val_F1Score: 0.8322 - val_loss: 0.4993 - learning_rate: 0.0010
# Epoch 61/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8615 - loss: 0.2431 - val_F1Score: 0.8337 - val_loss: 0.4902 - learning_rate: 0.0010
# Epoch 62/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8637 - loss: 0.2497 - val_F1Score: 0.8269 - val_loss: 0.5035 - learning_rate: 0.0010
# Epoch 63/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8604 - loss: 0.2450 - val_F1Score: 0.8307 - val_loss: 0.4878 - learning_rate: 0.0010
# Epoch 64/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8513 - loss: 0.2598 - val_F1Score: 0.8307 - val_loss: 0.4841 - learning_rate: 0.0010
# Epoch 65/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8696 - loss: 0.2305 - val_F1Score: 0.8124 - val_loss: 0.5064 - learning_rate: 0.0010
# Epoch 66/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8785 - loss: 0.2490 - val_F1Score: 0.8384 - val_loss: 0.4831 - learning_rate: 0.0010
# Epoch 67/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8359 - loss: 0.2649 - val_F1Score: 0.8399 - val_loss: 0.4817 - learning_rate: 0.0010
# Epoch 68/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8529 - loss: 0.2348 - val_F1Score: 0.8290 - val_loss: 0.4999 - learning_rate: 0.0010
# Epoch 69/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8516 - loss: 0.2596 - val_F1Score: 0.8418 - val_loss: 0.5015 - learning_rate: 0.0010
# Epoch 70/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8469 - loss: 0.2664 - val_F1Score: 0.8491 - val_loss: 0.5023 - learning_rate: 0.0010
# Epoch 71/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8827 - loss: 0.2153 - val_F1Score: 0.8479 - val_loss: 0.5204 - learning_rate: 0.0010
# Epoch 72/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8868 - loss: 0.2065 - val_F1Score: 0.8442 - val_loss: 0.5229 - learning_rate: 0.0010
# Epoch 73/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8755 - loss: 0.2292 - val_F1Score: 0.8423 - val_loss: 0.5166 - learning_rate: 0.0010
# Epoch 74/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8686 - loss: 0.2110 - val_F1Score: 0.8327 - val_loss: 0.5145 - learning_rate: 0.0010
# Epoch 75/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8683 - loss: 0.2168 - val_F1Score: 0.8322 - val_loss: 0.5276 - learning_rate: 0.0010
# Epoch 76/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8561 - loss: 0.2159 - val_F1Score: 0.8476 - val_loss: 0.5198 - learning_rate: 0.0010
# Epoch 77/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8729 - loss: 0.2339 - val_F1Score: 0.8473 - val_loss: 0.5259 - learning_rate: 0.0010
# Epoch 78/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8683 - loss: 0.2028 - val_F1Score: 0.8416 - val_loss: 0.5174 - learning_rate: 0.0010
# Epoch 79/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8660 - loss: 0.2320 - val_F1Score: 0.8460 - val_loss: 0.5350 - learning_rate: 0.0010
# Epoch 80/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8766 - loss: 0.2053 - val_F1Score: 0.8361 - val_loss: 0.5469 - learning_rate: 0.0010
# Epoch 81/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8968 - loss: 0.2189 - val_F1Score: 0.8389 - val_loss: 0.5706 - learning_rate: 0.0010
# Epoch 82/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8599 - loss: 0.2213 - val_F1Score: 0.8414 - val_loss: 0.5298 - learning_rate: 0.0010
# Epoch 83/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8923 - loss: 0.2026 - val_F1Score: 0.8319 - val_loss: 0.5413 - learning_rate: 0.0010
# Epoch 84/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8653 - loss: 0.2049 - val_F1Score: 0.8398 - val_loss: 0.5306 - learning_rate: 0.0010
# Epoch 85/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8895 - loss: 0.1874 - val_F1Score: 0.8505 - val_loss: 0.5194 - learning_rate: 0.0010
# Epoch 86/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8783 - loss: 0.2033 - val_F1Score: 0.8380 - val_loss: 0.5174 - learning_rate: 0.0010
# Epoch 87/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9014 - loss: 0.1874 - val_F1Score: 0.8490 - val_loss: 0.5335 - learning_rate: 0.0010
# Epoch 88/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8828 - loss: 0.1840 - val_F1Score: 0.8512 - val_loss: 0.5308 - learning_rate: 0.0010
# Epoch 89/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8880 - loss: 0.2177 - val_F1Score: 0.8487 - val_loss: 0.5358 - learning_rate: 0.0010
# Epoch 90/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8582 - loss: 0.2001 - val_F1Score: 0.8483 - val_loss: 0.5374 - learning_rate: 0.0010
# Epoch 91/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8824 - loss: 0.1897 - val_F1Score: 0.8336 - val_loss: 0.5547 - learning_rate: 0.0010
# Epoch 92/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8860 - loss: 0.1771 - val_F1Score: 0.8347 - val_loss: 0.5547 - learning_rate: 0.0010
# Epoch 93/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8734 - loss: 0.2042 - val_F1Score: 0.8481 - val_loss: 0.5560 - learning_rate: 0.0010
# Epoch 94/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8819 - loss: 0.1872 - val_F1Score: 0.8343 - val_loss: 0.5388 - learning_rate: 0.0010
# Epoch 95/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8925 - loss: 0.2018 - val_F1Score: 0.8476 - val_loss: 0.5325 - learning_rate: 0.0010
# Epoch 96/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8939 - loss: 0.1900 - val_F1Score: 0.8379 - val_loss: 0.5524 - learning_rate: 0.0010
# Epoch 97/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9043 - loss: 0.1624 - val_F1Score: 0.8613 - val_loss: 0.5673 - learning_rate: 0.0010
# Epoch 98/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9116 - loss: 0.1817 - val_F1Score: 0.8436 - val_loss: 0.5724 - learning_rate: 0.0010
# Epoch 99/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8902 - loss: 0.2062 - val_F1Score: 0.8329 - val_loss: 0.5714 - learning_rate: 0.0010
# Epoch 100/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8616 - loss: 0.1956 - val_F1Score: 0.8361 - val_loss: 0.5739 - learning_rate: 0.0010
# Epoch 101/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9031 - loss: 0.1776 - val_F1Score: 0.8327 - val_loss: 0.5574 - learning_rate: 0.0010
# Epoch 102/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8985 - loss: 0.1745 - val_F1Score: 0.8480 - val_loss: 0.5917 - learning_rate: 0.0010
# Epoch 103/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9285 - loss: 0.1639 - val_F1Score: 0.8528 - val_loss: 0.5903 - learning_rate: 0.0010
# Epoch 104/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8613 - loss: 0.1982 - val_F1Score: 0.8393 - val_loss: 0.5813 - learning_rate: 0.0010
# Epoch 105/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8706 - loss: 0.1819 - val_F1Score: 0.8419 - val_loss: 0.5945 - learning_rate: 0.0010
# Epoch 106/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8934 - loss: 0.1720 - val_F1Score: 0.8233 - val_loss: 0.5691 - learning_rate: 0.0010
# Epoch 107/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8884 - loss: 0.1675 - val_F1Score: 0.8270 - val_loss: 0.5907 - learning_rate: 0.0010
# Epoch 108/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9082 - loss: 0.1516 - val_F1Score: 0.8327 - val_loss: 0.6105 - learning_rate: 0.0010
# Epoch 109/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8772 - loss: 0.1709 - val_F1Score: 0.8341 - val_loss: 0.5817 - learning_rate: 0.0010
# Epoch 110/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9174 - loss: 0.1536 - val_F1Score: 0.8436 - val_loss: 0.5858 - learning_rate: 0.0010
# Epoch 111/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9023 - loss: 0.1558 - val_F1Score: 0.8227 - val_loss: 0.5643 - learning_rate: 0.0010
# Epoch 112/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9088 - loss: 0.1465 - val_F1Score: 0.8334 - val_loss: 0.5880 - learning_rate: 0.0010
# Epoch 113/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9048 - loss: 0.1392 - val_F1Score: 0.8358 - val_loss: 0.6012 - learning_rate: 0.0010
# Epoch 114/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9115 - loss: 0.1499 - val_F1Score: 0.8385 - val_loss: 0.5735 - learning_rate: 0.0010
# Epoch 115/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.8854 - loss: 0.1718 - val_F1Score: 0.8477 - val_loss: 0.5618 - learning_rate: 0.0010
# Epoch 116/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9205 - loss: 0.1507 - val_F1Score: 0.8470 - val_loss: 0.5782 - learning_rate: 0.0010
# Epoch 117/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8980 - loss: 0.1685 - val_F1Score: 0.8347 - val_loss: 0.5807 - learning_rate: 0.0010
# Epoch 118/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9158 - loss: 0.1467 - val_F1Score: 0.8344 - val_loss: 0.5930 - learning_rate: 0.0010
# Epoch 119/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9322 - loss: 0.1612 - val_F1Score: 0.8339 - val_loss: 0.5959 - learning_rate: 0.0010
# Epoch 120/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8912 - loss: 0.1741 - val_F1Score: 0.8349 - val_loss: 0.5852 - learning_rate: 0.0010
# Epoch 121/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8997 - loss: 0.1609 - val_F1Score: 0.8268 - val_loss: 0.6080 - learning_rate: 0.0010
# Epoch 122/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9072 - loss: 0.1521 - val_F1Score: 0.8368 - val_loss: 0.6347 - learning_rate: 0.0010
# Epoch 123/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8987 - loss: 0.1579 - val_F1Score: 0.8160 - val_loss: 0.6602 - learning_rate: 0.0010
# Epoch 124/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9167 - loss: 0.1564 - val_F1Score: 0.8231 - val_loss: 0.6255 - learning_rate: 0.0010
# Epoch 125/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8924 - loss: 0.1526 - val_F1Score: 0.8327 - val_loss: 0.6216 - learning_rate: 0.0010
# Epoch 126/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9284 - loss: 0.1528 - val_F1Score: 0.8454 - val_loss: 0.6158 - learning_rate: 0.0010
# Epoch 127/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9204 - loss: 0.1399 - val_F1Score: 0.8302 - val_loss: 0.6180 - learning_rate: 0.0010
# Epoch 128/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9136 - loss: 0.1553 - val_F1Score: 0.8400 - val_loss: 0.5848 - learning_rate: 0.0010
# Epoch 129/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9236 - loss: 0.1504 - val_F1Score: 0.8409 - val_loss: 0.6201 - learning_rate: 0.0010
# Epoch 130/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9003 - loss: 0.1480 - val_F1Score: 0.8340 - val_loss: 0.6134 - learning_rate: 0.0010
# Epoch 131/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9282 - loss: 0.1460 - val_F1Score: 0.8308 - val_loss: 0.6336 - learning_rate: 0.0010
# Epoch 132/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9124 - loss: 0.1475 - val_F1Score: 0.8408 - val_loss: 0.6363 - learning_rate: 0.0010
# Epoch 133/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9095 - loss: 0.1485 - val_F1Score: 0.8404 - val_loss: 0.6228 - learning_rate: 0.0010
# Epoch 134/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.8978 - loss: 0.1655 - val_F1Score: 0.8522 - val_loss: 0.5991 - learning_rate: 0.0010
# Epoch 135/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9122 - loss: 0.1687 - val_F1Score: 0.8399 - val_loss: 0.6256 - learning_rate: 0.0010
# Epoch 136/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9103 - loss: 0.1462 - val_F1Score: 0.8403 - val_loss: 0.6219 - learning_rate: 0.0010
# Epoch 137/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9085 - loss: 0.1536 - val_F1Score: 0.8385 - val_loss: 0.6714 - learning_rate: 0.0010
# Epoch 138/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9253 - loss: 0.1531 - val_F1Score: 0.8373 - val_loss: 0.6469 - learning_rate: 0.0010
# Epoch 139/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9272 - loss: 0.1203 - val_F1Score: 0.8457 - val_loss: 0.6795 - learning_rate: 0.0010
# Epoch 140/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9353 - loss: 0.1232 - val_F1Score: 0.8431 - val_loss: 0.6255 - learning_rate: 0.0010
# Epoch 141/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9295 - loss: 0.1293 - val_F1Score: 0.8268 - val_loss: 0.6757 - learning_rate: 0.0010
# Epoch 142/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9209 - loss: 0.1398 - val_F1Score: 0.8417 - val_loss: 0.6608 - learning_rate: 0.0010
# Epoch 143/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9266 - loss: 0.1498 - val_F1Score: 0.8418 - val_loss: 0.6884 - learning_rate: 0.0010
# Epoch 144/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9292 - loss: 0.1303 - val_F1Score: 0.8277 - val_loss: 0.7015 - learning_rate: 0.0010
# Epoch 145/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9166 - loss: 0.1427 - val_F1Score: 0.8370 - val_loss: 0.6475 - learning_rate: 0.0010
# Epoch 146/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9467 - loss: 0.1157 - val_F1Score: 0.8376 - val_loss: 0.6666 - learning_rate: 0.0010
# Epoch 147/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9057 - loss: 0.1458 - val_F1Score: 0.8391 - val_loss: 0.6692 - learning_rate: 0.0010
# Epoch 148/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9167 - loss: 0.1497 - val_F1Score: 0.8230 - val_loss: 0.6590 - learning_rate: 0.0010
# Epoch 149/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9111 - loss: 0.1654 - val_F1Score: 0.8346 - val_loss: 0.6399 - learning_rate: 0.0010
# Epoch 150/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9104 - loss: 0.1539 - val_F1Score: 0.8456 - val_loss: 0.6372 - learning_rate: 0.0010
# Epoch 151/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9198 - loss: 0.1387 - val_F1Score: 0.8455 - val_loss: 0.6611 - learning_rate: 0.0010
# Epoch 152/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9185 - loss: 0.1518 - val_F1Score: 0.8428 - val_loss: 0.6455 - learning_rate: 0.0010
# Epoch 153/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9356 - loss: 0.1038 - val_F1Score: 0.8363 - val_loss: 0.6765 - learning_rate: 0.0010
# Epoch 154/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9374 - loss: 0.1218 - val_F1Score: 0.8432 - val_loss: 0.7072 - learning_rate: 0.0010
# Epoch 155/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9025 - loss: 0.1252 - val_F1Score: 0.8423 - val_loss: 0.6735 - learning_rate: 0.0010
# Epoch 156/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9225 - loss: 0.1272 - val_F1Score: 0.8357 - val_loss: 0.6733 - learning_rate: 0.0010
# Epoch 157/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9490 - loss: 0.1110 - val_F1Score: 0.8461 - val_loss: 0.7035 - learning_rate: 0.0010
# Epoch 158/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9251 - loss: 0.1305 - val_F1Score: 0.8546 - val_loss: 0.6659 - learning_rate: 0.0010
# Epoch 159/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9352 - loss: 0.1085 - val_F1Score: 0.8523 - val_loss: 0.6998 - learning_rate: 0.0010
# Epoch 160/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9365 - loss: 0.1370 - val_F1Score: 0.8467 - val_loss: 0.6732 - learning_rate: 0.0010
# Epoch 161/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9336 - loss: 0.1163 - val_F1Score: 0.8483 - val_loss: 0.6941 - learning_rate: 0.0010
# Epoch 162/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9405 - loss: 0.1110 - val_F1Score: 0.8495 - val_loss: 0.6850 - learning_rate: 0.0010
# Epoch 163/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9463 - loss: 0.1064 - val_F1Score: 0.8446 - val_loss: 0.7055 - learning_rate: 0.0010
# Epoch 164/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9149 - loss: 0.1353 - val_F1Score: 0.8380 - val_loss: 0.6569 - learning_rate: 0.0010
# Epoch 165/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9415 - loss: 0.1185 - val_F1Score: 0.8401 - val_loss: 0.6906 - learning_rate: 0.0010
# Epoch 166/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9196 - loss: 0.1488 - val_F1Score: 0.8438 - val_loss: 0.7195 - learning_rate: 0.0010
# Epoch 167/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9378 - loss: 0.1255 - val_F1Score: 0.8439 - val_loss: 0.6721 - learning_rate: 0.0010
# Epoch 168/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9433 - loss: 0.1154 - val_F1Score: 0.8398 - val_loss: 0.6858 - learning_rate: 0.0010
# Epoch 169/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9389 - loss: 0.1083 - val_F1Score: 0.8436 - val_loss: 0.6669 - learning_rate: 0.0010
# Epoch 170/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9227 - loss: 0.1297 - val_F1Score: 0.8290 - val_loss: 0.6830 - learning_rate: 0.0010
# Epoch 171/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9247 - loss: 0.1063 - val_F1Score: 0.8376 - val_loss: 0.6671 - learning_rate: 0.0010
# Epoch 172/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9312 - loss: 0.1234 - val_F1Score: 0.8384 - val_loss: 0.6782 - learning_rate: 0.0010
# Epoch 173/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9197 - loss: 0.1294 - val_F1Score: 0.8495 - val_loss: 0.6777 - learning_rate: 0.0010
# Epoch 174/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9406 - loss: 0.1067 - val_F1Score: 0.8442 - val_loss: 0.6481 - learning_rate: 0.0010
# Epoch 175/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9273 - loss: 0.1090 - val_F1Score: 0.8578 - val_loss: 0.6838 - learning_rate: 0.0010
# Epoch 176/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9327 - loss: 0.1271 - val_F1Score: 0.8533 - val_loss: 0.6878 - learning_rate: 0.0010
# Epoch 177/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9244 - loss: 0.1226 - val_F1Score: 0.8471 - val_loss: 0.6784 - learning_rate: 0.0010
# Epoch 178/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9540 - loss: 0.1007 - val_F1Score: 0.8380 - val_loss: 0.7345 - learning_rate: 0.0010
# Epoch 179/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9408 - loss: 0.1171 - val_F1Score: 0.8539 - val_loss: 0.7234 - learning_rate: 0.0010
# Epoch 180/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9596 - loss: 0.1051 - val_F1Score: 0.8452 - val_loss: 0.7143 - learning_rate: 0.0010
# Epoch 181/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9558 - loss: 0.1006 - val_F1Score: 0.8528 - val_loss: 0.6861 - learning_rate: 0.0010
# Epoch 182/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9338 - loss: 0.1089 - val_F1Score: 0.8387 - val_loss: 0.7168 - learning_rate: 0.0010
# Epoch 183/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9259 - loss: 0.1358 - val_F1Score: 0.8548 - val_loss: 0.7022 - learning_rate: 0.0010
# Epoch 184/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9241 - loss: 0.1200 - val_F1Score: 0.8419 - val_loss: 0.7356 - learning_rate: 0.0010
# Epoch 185/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9435 - loss: 0.0968 - val_F1Score: 0.8491 - val_loss: 0.7180 - learning_rate: 0.0010
# Epoch 186/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9267 - loss: 0.1251 - val_F1Score: 0.8493 - val_loss: 0.7150 - learning_rate: 0.0010
# Epoch 187/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9419 - loss: 0.1023 - val_F1Score: 0.8378 - val_loss: 0.7177 - learning_rate: 0.0010
# Epoch 188/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9361 - loss: 0.1202 - val_F1Score: 0.8405 - val_loss: 0.7184 - learning_rate: 0.0010
# Epoch 189/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9463 - loss: 0.1083 - val_F1Score: 0.8383 - val_loss: 0.7129 - learning_rate: 0.0010
# Epoch 190/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9410 - loss: 0.1000 - val_F1Score: 0.8441 - val_loss: 0.7264 - learning_rate: 0.0010
# Epoch 191/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9362 - loss: 0.1075 - val_F1Score: 0.8488 - val_loss: 0.6904 - learning_rate: 0.0010
# Epoch 192/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9642 - loss: 0.0843 - val_F1Score: 0.8488 - val_loss: 0.6933 - learning_rate: 0.0010
# Epoch 193/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9339 - loss: 0.1044 - val_F1Score: 0.8513 - val_loss: 0.7435 - learning_rate: 0.0010
# Epoch 194/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9533 - loss: 0.1032 - val_F1Score: 0.8525 - val_loss: 0.7393 - learning_rate: 0.0010
# Epoch 195/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9529 - loss: 0.0936 - val_F1Score: 0.8449 - val_loss: 0.7549 - learning_rate: 0.0010
# Epoch 196/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9424 - loss: 0.1013 - val_F1Score: 0.8484 - val_loss: 0.7346 - learning_rate: 0.0010
# Epoch 197/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9240 - loss: 0.1279 - val_F1Score: 0.8366 - val_loss: 0.7115 - learning_rate: 0.0010
# Epoch 198/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9367 - loss: 0.1007 - val_F1Score: 0.8416 - val_loss: 0.6917 - learning_rate: 0.0010
# Epoch 199/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9513 - loss: 0.1098 - val_F1Score: 0.8316 - val_loss: 0.7536 - learning_rate: 0.0010
# Epoch 200/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9309 - loss: 0.1154 - val_F1Score: 0.8341 - val_loss: 0.7073 - learning_rate: 0.0010
# Epoch 201/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9260 - loss: 0.1405 - val_F1Score: 0.8304 - val_loss: 0.7129 - learning_rate: 0.0010
# Epoch 202/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9464 - loss: 0.1083 - val_F1Score: 0.8422 - val_loss: 0.7374 - learning_rate: 0.0010
# Epoch 203/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9488 - loss: 0.1158 - val_F1Score: 0.8393 - val_loss: 0.7042 - learning_rate: 0.0010
# Epoch 204/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9608 - loss: 0.0891 - val_F1Score: 0.8424 - val_loss: 0.7214 - learning_rate: 0.0010
# Epoch 205/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9096 - loss: 0.1156 - val_F1Score: 0.8402 - val_loss: 0.7206 - learning_rate: 0.0010
# Epoch 206/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9395 - loss: 0.1198 - val_F1Score: 0.8468 - val_loss: 0.7145 - learning_rate: 0.0010
# Epoch 207/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9526 - loss: 0.1028 - val_F1Score: 0.8477 - val_loss: 0.7436 - learning_rate: 0.0010
# Epoch 208/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9560 - loss: 0.1023 - val_F1Score: 0.8409 - val_loss: 0.7573 - learning_rate: 0.0010
# Epoch 209/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9513 - loss: 0.0957 - val_F1Score: 0.8370 - val_loss: 0.7629 - learning_rate: 0.0010
# Epoch 210/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9573 - loss: 0.1115 - val_F1Score: 0.8423 - val_loss: 0.7725 - learning_rate: 0.0010
# Epoch 211/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9494 - loss: 0.0921 - val_F1Score: 0.8394 - val_loss: 0.7559 - learning_rate: 0.0010
# Epoch 212/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9549 - loss: 0.0710 - val_F1Score: 0.8328 - val_loss: 0.7347 - learning_rate: 0.0010
# Epoch 213/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9527 - loss: 0.1135 - val_F1Score: 0.8345 - val_loss: 0.7379 - learning_rate: 0.0010
# Epoch 214/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9639 - loss: 0.0838 - val_F1Score: 0.8410 - val_loss: 0.7872 - learning_rate: 0.0010
# Epoch 215/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9513 - loss: 0.0952 - val_F1Score: 0.8338 - val_loss: 0.7432 - learning_rate: 0.0010
# Epoch 216/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9448 - loss: 0.1142 - val_F1Score: 0.8417 - val_loss: 0.7648 - learning_rate: 0.0010
# Epoch 217/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9234 - loss: 0.1140 - val_F1Score: 0.8280 - val_loss: 0.7725 - learning_rate: 0.0010
# Epoch 218/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9398 - loss: 0.1237 - val_F1Score: 0.8456 - val_loss: 0.7310 - learning_rate: 0.0010
# Epoch 219/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9343 - loss: 0.1128 - val_F1Score: 0.8232 - val_loss: 0.7760 - learning_rate: 0.0010
# Epoch 220/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9529 - loss: 0.0861 - val_F1Score: 0.8297 - val_loss: 0.7578 - learning_rate: 0.0010
# Epoch 221/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9348 - loss: 0.1034 - val_F1Score: 0.8356 - val_loss: 0.7217 - learning_rate: 0.0010
# Epoch 222/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9430 - loss: 0.0968 - val_F1Score: 0.8379 - val_loss: 0.7547 - learning_rate: 0.0010
# Epoch 223/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9417 - loss: 0.1040 - val_F1Score: 0.8395 - val_loss: 0.7633 - learning_rate: 0.0010
# Epoch 224/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9368 - loss: 0.1006 - val_F1Score: 0.8245 - val_loss: 0.7811 - learning_rate: 0.0010
# Epoch 225/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9609 - loss: 0.0762 - val_F1Score: 0.8358 - val_loss: 0.7939 - learning_rate: 0.0010
# Epoch 226/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9609 - loss: 0.1043 - val_F1Score: 0.8458 - val_loss: 0.7916 - learning_rate: 0.0010
# Epoch 227/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9437 - loss: 0.0912 - val_F1Score: 0.8323 - val_loss: 0.8000 - learning_rate: 0.0010
# Epoch 228/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9329 - loss: 0.0867 - val_F1Score: 0.8332 - val_loss: 0.7687 - learning_rate: 0.0010
# Epoch 229/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9470 - loss: 0.1093 - val_F1Score: 0.8303 - val_loss: 0.7781 - learning_rate: 0.0010
# Epoch 230/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9489 - loss: 0.0953 - val_F1Score: 0.8302 - val_loss: 0.7929 - learning_rate: 0.0010
# Epoch 231/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9471 - loss: 0.0930 - val_F1Score: 0.8287 - val_loss: 0.7897 - learning_rate: 0.0010
# Epoch 232/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9436 - loss: 0.0916 - val_F1Score: 0.8315 - val_loss: 0.8345 - learning_rate: 0.0010
# Epoch 233/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9554 - loss: 0.0900 - val_F1Score: 0.8332 - val_loss: 0.7911 - learning_rate: 0.0010
# Epoch 234/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9540 - loss: 0.0858 - val_F1Score: 0.8350 - val_loss: 0.7632 - learning_rate: 0.0010
# Epoch 235/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9403 - loss: 0.1030 - val_F1Score: 0.8347 - val_loss: 0.7863 - learning_rate: 0.0010
# Epoch 236/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9495 - loss: 0.1069 - val_F1Score: 0.8360 - val_loss: 0.7585 - learning_rate: 0.0010
# Epoch 237/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9346 - loss: 0.0889 - val_F1Score: 0.8274 - val_loss: 0.8140 - learning_rate: 0.0010
# Epoch 238/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9659 - loss: 0.0729 - val_F1Score: 0.8346 - val_loss: 0.8381 - learning_rate: 0.0010
# Epoch 239/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9505 - loss: 0.0892 - val_F1Score: 0.8430 - val_loss: 0.7927 - learning_rate: 0.0010
# Epoch 240/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9356 - loss: 0.0983 - val_F1Score: 0.8417 - val_loss: 0.7968 - learning_rate: 0.0010
# Epoch 241/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9521 - loss: 0.0805 - val_F1Score: 0.8317 - val_loss: 0.7947 - learning_rate: 0.0010
# Epoch 242/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9440 - loss: 0.0802 - val_F1Score: 0.8396 - val_loss: 0.8149 - learning_rate: 0.0010
# Epoch 243/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9522 - loss: 0.1016 - val_F1Score: 0.8395 - val_loss: 0.7913 - learning_rate: 0.0010
# Epoch 244/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9679 - loss: 0.0771 - val_F1Score: 0.8438 - val_loss: 0.8483 - learning_rate: 0.0010
# Epoch 245/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9584 - loss: 0.0961 - val_F1Score: 0.8465 - val_loss: 0.8331 - learning_rate: 0.0010
# Epoch 246/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9590 - loss: 0.0787 - val_F1Score: 0.8343 - val_loss: 0.7821 - learning_rate: 0.0010
# Epoch 247/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9586 - loss: 0.0761 - val_F1Score: 0.8146 - val_loss: 0.8687 - learning_rate: 0.0010
# Epoch 248/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9443 - loss: 0.1028 - val_F1Score: 0.8493 - val_loss: 0.8227 - learning_rate: 0.0010
# Epoch 249/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9456 - loss: 0.0912 - val_F1Score: 0.8408 - val_loss: 0.8179 - learning_rate: 0.0010
# Epoch 250/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9581 - loss: 0.0819 - val_F1Score: 0.8400 - val_loss: 0.8116 - learning_rate: 0.0010
# Epoch 251/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9614 - loss: 0.0843 - val_F1Score: 0.8420 - val_loss: 0.8403 - learning_rate: 0.0010
# Epoch 252/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9572 - loss: 0.0870 - val_F1Score: 0.8401 - val_loss: 0.8206 - learning_rate: 0.0010
# Epoch 253/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9565 - loss: 0.0777 - val_F1Score: 0.8457 - val_loss: 0.8161 - learning_rate: 0.0010
# Epoch 254/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9605 - loss: 0.0735 - val_F1Score: 0.8453 - val_loss: 0.8244 - learning_rate: 0.0010
# Epoch 255/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9600 - loss: 0.0726 - val_F1Score: 0.8501 - val_loss: 0.8321 - learning_rate: 0.0010
# Epoch 256/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9539 - loss: 0.0843 - val_F1Score: 0.8414 - val_loss: 0.8454 - learning_rate: 0.0010
# Epoch 257/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9591 - loss: 0.0694 - val_F1Score: 0.8422 - val_loss: 0.8150 - learning_rate: 0.0010
# Epoch 258/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9699 - loss: 0.0637 - val_F1Score: 0.8338 - val_loss: 0.7979 - learning_rate: 0.0010
# Epoch 259/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9453 - loss: 0.1047 - val_F1Score: 0.8412 - val_loss: 0.8166 - learning_rate: 0.0010
# Epoch 260/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9610 - loss: 0.0667 - val_F1Score: 0.8339 - val_loss: 0.8312 - learning_rate: 0.0010
# Epoch 261/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9439 - loss: 0.1094 - val_F1Score: 0.8396 - val_loss: 0.8266 - learning_rate: 0.0010
# Epoch 262/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9592 - loss: 0.0678 - val_F1Score: 0.8339 - val_loss: 0.8223 - learning_rate: 0.0010
# Epoch 263/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9512 - loss: 0.1310 - val_F1Score: 0.8414 - val_loss: 0.8137 - learning_rate: 0.0010
# Epoch 264/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9669 - loss: 0.0596 - val_F1Score: 0.8613 - val_loss: 0.7976 - learning_rate: 0.0010
# Epoch 265/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9653 - loss: 0.0789 - val_F1Score: 0.8374 - val_loss: 0.8234 - learning_rate: 0.0010
# Epoch 266/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9610 - loss: 0.0799 - val_F1Score: 0.8328 - val_loss: 0.8861 - learning_rate: 0.0010
# Epoch 267/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9605 - loss: 0.0723 - val_F1Score: 0.8392 - val_loss: 0.8226 - learning_rate: 0.0010
# Epoch 268/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9371 - loss: 0.1049 - val_F1Score: 0.8431 - val_loss: 0.8565 - learning_rate: 0.0010
# Epoch 269/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9728 - loss: 0.0699 - val_F1Score: 0.8386 - val_loss: 0.8406 - learning_rate: 0.0010
# Epoch 270/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9618 - loss: 0.0696 - val_F1Score: 0.8566 - val_loss: 0.8541 - learning_rate: 0.0010
# Epoch 271/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9495 - loss: 0.0719 - val_F1Score: 0.8495 - val_loss: 0.8698 - learning_rate: 0.0010
# Epoch 272/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9457 - loss: 0.0642 - val_F1Score: 0.8564 - val_loss: 0.8690 - learning_rate: 0.0010
# Epoch 273/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9652 - loss: 0.0751 - val_F1Score: 0.8312 - val_loss: 0.9071 - learning_rate: 0.0010
# Epoch 274/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9528 - loss: 0.0729 - val_F1Score: 0.8409 - val_loss: 0.8640 - learning_rate: 0.0010
# Epoch 275/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9660 - loss: 0.0806 - val_F1Score: 0.8414 - val_loss: 0.8607 - learning_rate: 0.0010
# Epoch 276/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9592 - loss: 0.0813 - val_F1Score: 0.8522 - val_loss: 0.8409 - learning_rate: 0.0010
# Epoch 277/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9539 - loss: 0.1035 - val_F1Score: 0.8352 - val_loss: 0.8924 - learning_rate: 0.0010
# Epoch 278/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9544 - loss: 0.0824 - val_F1Score: 0.8394 - val_loss: 0.8538 - learning_rate: 0.0010
# Epoch 279/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9567 - loss: 0.0725 - val_F1Score: 0.8392 - val_loss: 0.8634 - learning_rate: 0.0010
# Epoch 280/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9627 - loss: 0.0689 - val_F1Score: 0.8291 - val_loss: 0.8540 - learning_rate: 0.0010
# Epoch 281/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9587 - loss: 0.0749 - val_F1Score: 0.8414 - val_loss: 0.8461 - learning_rate: 0.0010
# Epoch 282/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9725 - loss: 0.0570 - val_F1Score: 0.8350 - val_loss: 0.8800 - learning_rate: 0.0010
# Epoch 283/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9616 - loss: 0.0862 - val_F1Score: 0.8269 - val_loss: 0.8818 - learning_rate: 0.0010
# Epoch 284/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9577 - loss: 0.0990 - val_F1Score: 0.8414 - val_loss: 0.8752 - learning_rate: 0.0010
# Epoch 285/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9485 - loss: 0.0935 - val_F1Score: 0.8314 - val_loss: 0.8614 - learning_rate: 0.0010
# Epoch 286/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9540 - loss: 0.0825 - val_F1Score: 0.8350 - val_loss: 0.8872 - learning_rate: 0.0010
# Epoch 287/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9582 - loss: 0.0671 - val_F1Score: 0.8390 - val_loss: 0.8760 - learning_rate: 0.0010
# Epoch 288/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9599 - loss: 0.0748 - val_F1Score: 0.8421 - val_loss: 0.8797 - learning_rate: 0.0010
# Epoch 289/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9664 - loss: 0.0730 - val_F1Score: 0.8474 - val_loss: 0.8630 - learning_rate: 0.0010
# Epoch 290/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9562 - loss: 0.0947 - val_F1Score: 0.8274 - val_loss: 0.8885 - learning_rate: 0.0010
# Epoch 291/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9489 - loss: 0.0948 - val_F1Score: 0.8335 - val_loss: 0.8193 - learning_rate: 0.0010
# Epoch 292/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9434 - loss: 0.0970 - val_F1Score: 0.8374 - val_loss: 0.8422 - learning_rate: 0.0010
# Epoch 293/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9599 - loss: 0.0806 - val_F1Score: 0.8500 - val_loss: 0.8650 - learning_rate: 0.0010
# Epoch 294/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9322 - loss: 0.0716 - val_F1Score: 0.8406 - val_loss: 0.8506 - learning_rate: 0.0010
# Epoch 295/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9583 - loss: 0.0935 - val_F1Score: 0.8184 - val_loss: 0.8708 - learning_rate: 0.0010
# Epoch 296/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9471 - loss: 0.0740 - val_F1Score: 0.8368 - val_loss: 0.8644 - learning_rate: 0.0010
# Epoch 297/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9604 - loss: 0.0658 - val_F1Score: 0.8466 - val_loss: 0.8214 - learning_rate: 0.0010
# Epoch 298/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9428 - loss: 0.0804 - val_F1Score: 0.8536 - val_loss: 0.8148 - learning_rate: 0.0010
# Epoch 299/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9637 - loss: 0.0703 - val_F1Score: 0.8514 - val_loss: 0.7989 - learning_rate: 0.0010
# Epoch 300/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9779 - loss: 0.0584 - val_F1Score: 0.8483 - val_loss: 0.8979 - learning_rate: 0.0010
# Epoch 301/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9606 - loss: 0.0629 - val_F1Score: 0.8432 - val_loss: 0.8580 - learning_rate: 0.0010
# Epoch 302/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9495 - loss: 0.0920 - val_F1Score: 0.8498 - val_loss: 0.8111 - learning_rate: 0.0010
# Epoch 303/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9641 - loss: 0.0745 - val_F1Score: 0.8319 - val_loss: 0.8758 - learning_rate: 0.0010
# Epoch 304/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9563 - loss: 0.0777 - val_F1Score: 0.8337 - val_loss: 0.8335 - learning_rate: 0.0010
# Epoch 305/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9600 - loss: 0.0705 - val_F1Score: 0.8360 - val_loss: 0.9074 - learning_rate: 0.0010
# Epoch 306/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9602 - loss: 0.0710 - val_F1Score: 0.8469 - val_loss: 0.8734 - learning_rate: 0.0010
# Epoch 307/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9566 - loss: 0.0654 - val_F1Score: 0.8386 - val_loss: 0.8937 - learning_rate: 0.0010
# Epoch 308/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9815 - loss: 0.0502 - val_F1Score: 0.8497 - val_loss: 0.8875 - learning_rate: 0.0010
# Epoch 309/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9431 - loss: 0.0667 - val_F1Score: 0.8373 - val_loss: 0.8963 - learning_rate: 0.0010
# Epoch 310/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9696 - loss: 0.0703 - val_F1Score: 0.8410 - val_loss: 0.8789 - learning_rate: 0.0010
# Epoch 311/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9413 - loss: 0.0797 - val_F1Score: 0.8457 - val_loss: 0.8829 - learning_rate: 0.0010
# Epoch 312/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9650 - loss: 0.0705 - val_F1Score: 0.8437 - val_loss: 0.8724 - learning_rate: 0.0010
# Epoch 313/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9637 - loss: 0.0820 - val_F1Score: 0.8345 - val_loss: 0.8856 - learning_rate: 0.0010
# Epoch 314/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9603 - loss: 0.0896 - val_F1Score: 0.8233 - val_loss: 0.9340 - learning_rate: 0.0010
# Epoch 315/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9592 - loss: 0.0801 - val_F1Score: 0.8305 - val_loss: 0.8708 - learning_rate: 0.0010
# Epoch 316/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9681 - loss: 0.0541 - val_F1Score: 0.8403 - val_loss: 0.8998 - learning_rate: 0.0010
# Epoch 317/1000
# ...
# Epoch 896/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9690 - loss: 0.0454 - val_F1Score: 0.8371 - val_loss: 1.2085 - learning_rate: 0.0010
# Epoch 897/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9839 - loss: 0.0404 - val_F1Score: 0.8447 - val_loss: 1.2539 - learning_rate: 0.0010
# Epoch 898/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9731 - loss: 0.0411 - val_F1Score: 0.8427 - val_loss: 1.2109 - learning_rate: 0.0010
# Epoch 899/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9736 - loss: 0.0557 - val_F1Score: 0.8441 - val_loss: 1.2314 - learning_rate: 0.0010
# Epoch 900/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9797 - loss: 0.0393 - val_F1Score: 0.8459 - val_loss: 1.2131 - learning_rate: 0.0010
# Epoch 901/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9834 - loss: 0.0274 - val_F1Score: 0.8451 - val_loss: 1.2532 - learning_rate: 0.0010
# Epoch 902/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9917 - loss: 0.0226 - val_F1Score: 0.8478 - val_loss: 1.2594 - learning_rate: 0.0010
# Epoch 903/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9891 - loss: 0.0206 - val_F1Score: 0.8436 - val_loss: 1.2843 - learning_rate: 0.0010
# Epoch 904/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9754 - loss: 0.0354 - val_F1Score: 0.8495 - val_loss: 1.2807 - learning_rate: 0.0010
# Epoch 905/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9842 - loss: 0.0308 - val_F1Score: 0.8395 - val_loss: 1.2960 - learning_rate: 0.0010
# Epoch 906/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9828 - loss: 0.0417 - val_F1Score: 0.8467 - val_loss: 1.2391 - learning_rate: 0.0010
# Epoch 907/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9836 - loss: 0.0301 - val_F1Score: 0.8420 - val_loss: 1.2568 - learning_rate: 0.0010
# Epoch 908/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9854 - loss: 0.0295 - val_F1Score: 0.8346 - val_loss: 1.2743 - learning_rate: 0.0010
# Epoch 909/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9891 - loss: 0.0265 - val_F1Score: 0.8475 - val_loss: 1.3188 - learning_rate: 0.0010
# Epoch 910/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9835 - loss: 0.0285 - val_F1Score: 0.8438 - val_loss: 1.3051 - learning_rate: 0.0010
# Epoch 911/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9918 - loss: 0.0202 - val_F1Score: 0.8462 - val_loss: 1.3145 - learning_rate: 0.0010
# Epoch 912/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9861 - loss: 0.0250 - val_F1Score: 0.8485 - val_loss: 1.3089 - learning_rate: 0.0010
# Epoch 913/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9771 - loss: 0.0254 - val_F1Score: 0.8458 - val_loss: 1.3888 - learning_rate: 0.0010
# Epoch 914/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9851 - loss: 0.0413 - val_F1Score: 0.8400 - val_loss: 1.3125 - learning_rate: 0.0010
# Epoch 915/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9739 - loss: 0.0423 - val_F1Score: 0.8373 - val_loss: 1.3164 - learning_rate: 0.0010
# Epoch 916/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9800 - loss: 0.0314 - val_F1Score: 0.8257 - val_loss: 1.3109 - learning_rate: 0.0010
# Epoch 917/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9833 - loss: 0.0545 - val_F1Score: 0.8179 - val_loss: 1.2959 - learning_rate: 0.0010
# Epoch 918/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9789 - loss: 0.0481 - val_F1Score: 0.8259 - val_loss: 1.2449 - learning_rate: 0.0010
# Epoch 919/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9869 - loss: 0.0225 - val_F1Score: 0.8185 - val_loss: 1.2745 - learning_rate: 0.0010
# Epoch 920/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9683 - loss: 0.0453 - val_F1Score: 0.8429 - val_loss: 1.2166 - learning_rate: 0.0010
# Epoch 921/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9821 - loss: 0.0315 - val_F1Score: 0.8269 - val_loss: 1.2105 - learning_rate: 0.0010
# Epoch 922/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9780 - loss: 0.0454 - val_F1Score: 0.8229 - val_loss: 1.2430 - learning_rate: 0.0010
# Epoch 923/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9611 - loss: 0.0500 - val_F1Score: 0.8358 - val_loss: 1.2258 - learning_rate: 0.0010
# Epoch 924/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9862 - loss: 0.0257 - val_F1Score: 0.8394 - val_loss: 1.2025 - learning_rate: 0.0010
# Epoch 925/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9757 - loss: 0.0400 - val_F1Score: 0.8416 - val_loss: 1.1942 - learning_rate: 0.0010
# Epoch 926/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9844 - loss: 0.0354 - val_F1Score: 0.8503 - val_loss: 1.2005 - learning_rate: 0.0010
# Epoch 927/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9889 - loss: 0.0188 - val_F1Score: 0.8264 - val_loss: 1.2264 - learning_rate: 0.0010
# Epoch 928/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9737 - loss: 0.0475 - val_F1Score: 0.8328 - val_loss: 1.2678 - learning_rate: 0.0010
# Epoch 929/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9843 - loss: 0.0283 - val_F1Score: 0.8364 - val_loss: 1.3000 - learning_rate: 0.0010
# Epoch 930/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9733 - loss: 0.0432 - val_F1Score: 0.8360 - val_loss: 1.2314 - learning_rate: 0.0010
# Epoch 931/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9861 - loss: 0.0314 - val_F1Score: 0.8362 - val_loss: 1.2611 - learning_rate: 0.0010
# Epoch 932/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9850 - loss: 0.0385 - val_F1Score: 0.8361 - val_loss: 1.2922 - learning_rate: 0.0010
# Epoch 933/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9818 - loss: 0.0286 - val_F1Score: 0.8407 - val_loss: 1.3244 - learning_rate: 0.0010
# Epoch 934/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9700 - loss: 0.0476 - val_F1Score: 0.8331 - val_loss: 1.2408 - learning_rate: 0.0010
# Epoch 935/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9799 - loss: 0.0391 - val_F1Score: 0.8267 - val_loss: 1.2374 - learning_rate: 0.0010
# Epoch 936/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9802 - loss: 0.0497 - val_F1Score: 0.8321 - val_loss: 1.2715 - learning_rate: 0.0010
# Epoch 937/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9811 - loss: 0.0381 - val_F1Score: 0.8224 - val_loss: 1.2453 - learning_rate: 0.0010
# Epoch 938/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9836 - loss: 0.0440 - val_F1Score: 0.8289 - val_loss: 1.2771 - learning_rate: 0.0010
# Epoch 939/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9874 - loss: 0.0273 - val_F1Score: 0.8328 - val_loss: 1.3122 - learning_rate: 0.0010
# Epoch 940/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9827 - loss: 0.0347 - val_F1Score: 0.8292 - val_loss: 1.2836 - learning_rate: 0.0010
# Epoch 941/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9769 - loss: 0.0396 - val_F1Score: 0.8408 - val_loss: 1.2620 - learning_rate: 0.0010
# Epoch 942/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9858 - loss: 0.0379 - val_F1Score: 0.8343 - val_loss: 1.2867 - learning_rate: 0.0010
# Epoch 943/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9850 - loss: 0.0359 - val_F1Score: 0.8249 - val_loss: 1.2790 - learning_rate: 0.0010
# Epoch 944/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9831 - loss: 0.0473 - val_F1Score: 0.8301 - val_loss: 1.2569 - learning_rate: 0.0010
# Epoch 945/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9810 - loss: 0.0359 - val_F1Score: 0.8404 - val_loss: 1.2348 - learning_rate: 0.0010
# Epoch 946/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9723 - loss: 0.0618 - val_F1Score: 0.8427 - val_loss: 1.2511 - learning_rate: 0.0010
# Epoch 947/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9741 - loss: 0.0284 - val_F1Score: 0.8433 - val_loss: 1.2667 - learning_rate: 0.0010
# Epoch 948/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9870 - loss: 0.0358 - val_F1Score: 0.8308 - val_loss: 1.2602 - learning_rate: 0.0010
# Epoch 949/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9884 - loss: 0.0210 - val_F1Score: 0.8407 - val_loss: 1.2625 - learning_rate: 0.0010
# Epoch 950/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9654 - loss: 0.0629 - val_F1Score: 0.8391 - val_loss: 1.2917 - learning_rate: 0.0010
# Epoch 951/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9741 - loss: 0.0411 - val_F1Score: 0.8334 - val_loss: 1.2862 - learning_rate: 0.0010
# Epoch 952/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9824 - loss: 0.0306 - val_F1Score: 0.8346 - val_loss: 1.3082 - learning_rate: 0.0010
# Epoch 953/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9901 - loss: 0.0258 - val_F1Score: 0.8468 - val_loss: 1.3078 - learning_rate: 0.0010
# Epoch 954/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9895 - loss: 0.0319 - val_F1Score: 0.8511 - val_loss: 1.2995 - learning_rate: 0.0010
# Epoch 955/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9721 - loss: 0.0326 - val_F1Score: 0.8441 - val_loss: 1.3434 - learning_rate: 0.0010
# Epoch 956/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9852 - loss: 0.0315 - val_F1Score: 0.8392 - val_loss: 1.3350 - learning_rate: 0.0010
# Epoch 957/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9861 - loss: 0.0437 - val_F1Score: 0.8389 - val_loss: 1.3364 - learning_rate: 0.0010
# Epoch 958/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9790 - loss: 0.0357 - val_F1Score: 0.8285 - val_loss: 1.2961 - learning_rate: 0.0010
# Epoch 959/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9799 - loss: 0.0291 - val_F1Score: 0.8441 - val_loss: 1.3080 - learning_rate: 0.0010
# Epoch 960/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9864 - loss: 0.0265 - val_F1Score: 0.8376 - val_loss: 1.3173 - learning_rate: 0.0010
# Epoch 961/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9803 - loss: 0.0308 - val_F1Score: 0.8353 - val_loss: 1.2991 - learning_rate: 0.0010
# Epoch 962/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9728 - loss: 0.0397 - val_F1Score: 0.8326 - val_loss: 1.3115 - learning_rate: 0.0010
# Epoch 963/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9742 - loss: 0.0249 - val_F1Score: 0.8450 - val_loss: 1.3082 - learning_rate: 0.0010
# Epoch 964/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9765 - loss: 0.0446 - val_F1Score: 0.8291 - val_loss: 1.3376 - learning_rate: 0.0010
# Epoch 965/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9714 - loss: 0.0373 - val_F1Score: 0.8326 - val_loss: 1.2757 - learning_rate: 0.0010
# Epoch 966/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9809 - loss: 0.0341 - val_F1Score: 0.8497 - val_loss: 1.2830 - learning_rate: 0.0010
# Epoch 967/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9842 - loss: 0.0298 - val_F1Score: 0.8369 - val_loss: 1.3244 - learning_rate: 0.0010
# Epoch 968/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9872 - loss: 0.0302 - val_F1Score: 0.8359 - val_loss: 1.3138 - learning_rate: 0.0010
# Epoch 969/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9901 - loss: 0.0265 - val_F1Score: 0.8434 - val_loss: 1.3606 - learning_rate: 0.0010
# Epoch 970/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9836 - loss: 0.0354 - val_F1Score: 0.8472 - val_loss: 1.3317 - learning_rate: 0.0010
# Epoch 971/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9765 - loss: 0.0472 - val_F1Score: 0.8377 - val_loss: 1.2746 - learning_rate: 0.0010
# Epoch 972/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9804 - loss: 0.0601 - val_F1Score: 0.8523 - val_loss: 1.2888 - learning_rate: 0.0010
# Epoch 973/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9879 - loss: 0.0357 - val_F1Score: 0.8360 - val_loss: 1.2454 - learning_rate: 0.0010
# Epoch 974/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9868 - loss: 0.0351 - val_F1Score: 0.8450 - val_loss: 1.2720 - learning_rate: 0.0010
# Epoch 975/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9813 - loss: 0.0383 - val_F1Score: 0.8276 - val_loss: 1.2948 - learning_rate: 0.0010
# Epoch 976/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9814 - loss: 0.0288 - val_F1Score: 0.8324 - val_loss: 1.2943 - learning_rate: 0.0010
# Epoch 977/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9836 - loss: 0.0361 - val_F1Score: 0.8494 - val_loss: 1.2965 - learning_rate: 0.0010
# Epoch 978/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9745 - loss: 0.0398 - val_F1Score: 0.8519 - val_loss: 1.3012 - learning_rate: 0.0010
# Epoch 979/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9742 - loss: 0.0472 - val_F1Score: 0.8381 - val_loss: 1.2579 - learning_rate: 0.0010
# Epoch 980/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9793 - loss: 0.0299 - val_F1Score: 0.8401 - val_loss: 1.2533 - learning_rate: 0.0010
# Epoch 981/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9808 - loss: 0.0299 - val_F1Score: 0.8346 - val_loss: 1.2557 - learning_rate: 0.0010
# Epoch 982/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9896 - loss: 0.0337 - val_F1Score: 0.8316 - val_loss: 1.2519 - learning_rate: 0.0010
# Epoch 983/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9835 - loss: 0.0245 - val_F1Score: 0.8455 - val_loss: 1.2754 - learning_rate: 0.0010
# Epoch 984/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9715 - loss: 0.0541 - val_F1Score: 0.8331 - val_loss: 1.2607 - learning_rate: 0.0010
# Epoch 985/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9819 - loss: 0.0282 - val_F1Score: 0.8447 - val_loss: 1.2579 - learning_rate: 0.0010
# Epoch 986/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9756 - loss: 0.0353 - val_F1Score: 0.8330 - val_loss: 1.2915 - learning_rate: 0.0010
# Epoch 987/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9854 - loss: 0.0314 - val_F1Score: 0.8323 - val_loss: 1.2866 - learning_rate: 0.0010
# Epoch 988/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9875 - loss: 0.0333 - val_F1Score: 0.8360 - val_loss: 1.2898 - learning_rate: 0.0010
# Epoch 989/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9701 - loss: 0.0585 - val_F1Score: 0.8350 - val_loss: 1.2903 - learning_rate: 0.0010
# Epoch 990/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9922 - loss: 0.0166 - val_F1Score: 0.8381 - val_loss: 1.3371 - learning_rate: 0.0010
# Epoch 991/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9898 - loss: 0.0276 - val_F1Score: 0.8394 - val_loss: 1.2933 - learning_rate: 0.0010
# Epoch 992/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9835 - loss: 0.0316 - val_F1Score: 0.8346 - val_loss: 1.3376 - learning_rate: 0.0010
# Epoch 993/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9587 - loss: 0.0369 - val_F1Score: 0.8428 - val_loss: 1.4161 - learning_rate: 0.0010
# Epoch 994/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9889 - loss: 0.0245 - val_F1Score: 0.8421 - val_loss: 1.4427 - learning_rate: 0.0010
# Epoch 995/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - F1Score: 0.9762 - loss: 0.0285 - val_F1Score: 0.8486 - val_loss: 1.3695 - learning_rate: 0.0010
# Epoch 996/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9909 - loss: 0.0343 - val_F1Score: 0.8454 - val_loss: 1.3942 - learning_rate: 0.0010
# Epoch 997/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9764 - loss: 0.0412 - val_F1Score: 0.8495 - val_loss: 1.3331 - learning_rate: 0.0010
# Epoch 998/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9764 - loss: 0.0396 - val_F1Score: 0.8394 - val_loss: 1.3201 - learning_rate: 0.0010
# Epoch 999/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9813 - loss: 0.0334 - val_F1Score: 0.8300 - val_loss: 1.2617 - learning_rate: 0.0010
# Epoch 1000/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - F1Score: 0.9764 - loss: 0.0568 - val_F1Score: 0.8363 - val_loss: 1.2632 - learning_rate: 0.0010

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['F1Score'])
plt.plot(history.history['val_F1Score'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
model.evaluate(xtest,ytest)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - F1Score: 0.9959 - loss: 0.0292
# [0.05878498777747154,
#  <tf.Tensor: shape=(5,), dtype=float32, numpy=
#  array([0.9708737, 1.       , 0.9974554, 0.9951922, 0.9983498],
#        dtype=float32)>]
